# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importando dados de emprestimos

# %%
data_sources = [
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv',
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv'
]

data_frames = []
for url in data_sources:
  data_frames.append(pd.read_csv(url, on_bad_lines='skip'))

# %%
data_frames[6]
# Out:
#         id_emprestimo codigo_barras                 data_renovacao  \
# 0             1535182       E002010                            NaN
# 1             1535183    2010049079  2013/07/16 17:25:10.615000000
# 2             1535184    2011013154  2013/07/16 21:03:55.928000000
# 3             1535185    2011001485  2013/07/16 21:03:55.802000000
# 4             1535186    2012038972  2013/07/16 17:51:37.835000000
# ...               ...           ...                            ...
# 124191        1670344    2010029617                            NaN
# 124192        1670347    2008046871                            NaN
# 124193        1670348    2011033605                            NaN
# 124194        1670349    2008046870                            NaN
# 124195        1670350    2011033600                            NaN
#
#                       data_emprestimo                 data_devolucao  \
# 0       2013/07/01 07:47:13.765000000  2013/08/06 20:28:21.000000000
# ...

# %% [markdown]
# ## Unindo os datasets de emprestimos

# %%
emprestimos = pd.concat(data_frames)
emprestimos
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 0             709684       L095049                            NaN
# 1             709685       L167050                            NaN
# 2             709686    2006017618  2010/01/26 08:07:01.738000000
# 3             709687       L184117  2010/01/18 11:07:46.470000000
# 4             709684       L095049                            NaN
# ...              ...           ...                            ...
# 26556        2989086    2008047044                            NaN
# 26557        2989087    2008047047                            NaN
# 26558        2989088    2010052905                            NaN
# 26559        2989089    2010048023                            NaN
# 26560        2989090    2013106838                            NaN
#
#                      data_emprestimo                 data_devolucao  \
# 0      2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# ## Verificando a existência de duplicadas e dados nulos e excluindo-os

# %%
# verificar dados duplicados

emprestimos.duplicated().sum()
# Out:
# 245046

# %%
# excluir dados duplicados

emprestimos.drop_duplicates(inplace=True)

# %%
emprestimos['data_emprestimo'] = pd.to_datetime(emprestimos['data_emprestimo'])
emprestimos['data_devolucao'] = pd.to_datetime(emprestimos['data_devolucao'])
emprestimos['data_renovacao'] = pd.to_datetime(emprestimos['data_renovacao'])

emprestimos
# Out:
#        id_emprestimo codigo_barras          data_renovacao  \
# 0             709684       L095049                     NaT
# 1             709685       L167050                     NaT
# 2             709686    2006017618 2010-01-26 08:07:01.738
# 3             709687       L184117 2010-01-18 11:07:46.470
# 8             709688    2007027500 2010-01-19 15:59:26.464
# ...              ...           ...                     ...
# 26556        2989086    2008047044                     NaT
# 26557        2989087    2008047047                     NaT
# 26558        2989088    2010052905                     NaT
# 26559        2989089    2010048023                     NaT
# 26560        2989090    2013106838                     NaT
#
#               data_emprestimo          data_devolucao  matricula_ou_siape  \
# 0     2010-01-04 07:44:10.721 2010-01-05 16:26:12.662        2.008023e+09
# 1     2010-01-04 07:44:10.750 2010-01-12 07:34:13.934        2.008023e+09
# ...

# %%
emprestimos
# Out:
#        id_emprestimo codigo_barras          data_renovacao  \
# 0             709684       L095049                     NaT
# 1             709685       L167050                     NaT
# 2             709686    2006017618 2010-01-26 08:07:01.738
# 3             709687       L184117 2010-01-18 11:07:46.470
# 8             709688    2007027500 2010-01-19 15:59:26.464
# ...              ...           ...                     ...
# 26556        2989086    2008047044                     NaT
# 26557        2989087    2008047047                     NaT
# 26558        2989088    2010052905                     NaT
# 26559        2989089    2010048023                     NaT
# 26560        2989090    2013106838                     NaT
#
#               data_emprestimo          data_devolucao  matricula_ou_siape  \
# 0     2010-01-04 07:44:10.721 2010-01-05 16:26:12.662        2.008023e+09
# 1     2010-01-04 07:44:10.750 2010-01-12 07:34:13.934        2.008023e+09
# ...

# %% [markdown]
# ## Importando dados dos exemplares do acervo

# %%
exemplares = pd.read_parquet('dados_exemplares.parquet')
exemplares
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %% [markdown]
# ## Mesclando os datasets

# %%
dados_biblioteca = pd.merge(emprestimos, exemplares, on='codigo_barras')
dados_biblioteca
# Out:
#          id_emprestimo codigo_barras          data_renovacao  \
# 0               709684       L095049                     NaT
# 1               726965       L095049 2010-03-31 12:41:08.684
# 2               709685       L167050                     NaT
# 3               717763       L167050                     NaT
# 4               729996       L167050 2010-03-17 09:08:26.874
# ...                ...           ...                     ...
# 1834374        2989018    2009036492                     NaT
# 1834375        2989020    2014062640                     NaT
# 1834376        2989032    2018003324                     NaT
# 1834377        2989049    2006024313                     NaT
# 1834378        2989061    2018031352                     NaT
#
#                 data_emprestimo          data_devolucao  matricula_ou_siape  \
# 0       2010-01-04 07:44:10.721 2010-01-05 16:26:12.662        2.008023e+09
# 1       2010-03-01 12:40:56.212 2010-04-30 14:42:35.366        2.009122e+09
# ...

# %% [markdown]
# ##Limpeza

# %% [markdown]
# ### Verificando dados nulos

# %%
dados_biblioteca.isnull().sum()
# Out:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1034705
# data_emprestimo               0
# data_devolucao             6173
# matricula_ou_siape         2687
# tipo_vinculo_usuario          0
# id_exemplar                   0
# colecao                       0
# biblioteca                    0
# status_material               0
# localizacao                   0
# registro_sistema              0
# dtype: int64

# %% [markdown]
# Os dados nulos em data_renovação existem porque nem todos os emprestimos foram renovados por mais tempo, portanto vou mantê-los.

# %%
dados_biblioteca['matricula_ou_siape'] = dados_biblioteca['matricula_ou_siape'].astype('str')
dados_biblioteca.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         726965       L095049 2010-03-31 12:41:08.684
# 2         709685       L167050                     NaT
# 3         717763       L167050                     NaT
# 4         729996       L167050 2010-03-17 09:08:26.874
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 1 2010-03-01 12:40:56.212 2010-04-30 14:42:35.366       2009121584.0
# 2 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934       2008023265.0
# 3 2010-02-11 11:16:30.335 2010-03-04 08:54:32.262       2008050352.0
# 4 2010-03-04 13:36:26.599 2010-03-31 18:04:29.669        200722565.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# ### Usando condições para definir as áreas de conhecimento dos livros com base no número da localização

# %% [markdown]
# 000 a 099: Generalidades. Ciência e conhecimento.
#
# ---
#
#
# 100 a 199: Filosofia e psicologia.
#
# ---
#
#
# 200 a 299: Religião.
#
# ---
#
#
# 300 a 399: Ciências sociais.
#
# ---
#
#
# 400 a 499: Classe vaga. Provisoriamente não ocupada.
#
# ---
#
#
# 500 a 599: Matemática e ciências naturais.
#
# ---
#
#
# 600 a 699: Ciências aplicadas.
#
# ---
#
#
# 700 a 799: Belas artes.
#
# ---
#
#
# 800 a 899: Linguagem. Língua. Linguística.
#
# ---
#
#
# 900 a 999: Geografia. Biografia. História.

# %%
def localizar_area(localizacao):
  if localizacao >= 000 and localizacao < 99:
    return 'Generalidades. Ciência e conhecimento'
  elif localizacao >= 100 and localizacao < 199:
    return 'Filosofia e psicologia'
  elif localizacao >= 200 and localizacao < 299:
    return 'Religião'
  elif localizacao >= 300 and localizacao < 399:
    return 'Ciências Sociais'
  elif localizacao >= 400 and localizacao < 499:
    return 'Classe vaga. Provisoriamente não ocupada'
  elif localizacao >= 500 and localizacao < 599:
    return 'Matemática e ciências naturais'
  elif localizacao >= 600 and localizacao < 699:
    return 'Ciências aplicadas'
  elif localizacao >= 700 and localizacao < 799:
    return 'Belas artes'
  elif localizacao >= 800 and localizacao < 899:
    return 'Linguagem. Língua. Linguística'
  elif localizacao >= 900 and localizacao < 999:
    return 'Geografia. Biografia. História'
  else:
    return 'Não identificado'

# %%
dados_biblioteca['area_conhecimento'] = dados_biblioteca['localizacao'].apply(localizar_area)
dados_biblioteca.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         726965       L095049 2010-03-31 12:41:08.684
# 2         709685       L167050                     NaT
# 3         717763       L167050                     NaT
# 4         729996       L167050 2010-03-17 09:08:26.874
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 1 2010-03-01 12:40:56.212 2010-04-30 14:42:35.366       2009121584.0
# 2 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934       2008023265.0
# 3 2010-02-11 11:16:30.335 2010-03-04 08:54:32.262       2008050352.0
# 4 2010-03-04 13:36:26.599 2010-03-31 18:04:29.669        200722565.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# ## Análise exploratória de dados e DateTime

# %%
dados_biblioteca.dtypes
# Out:
# id_emprestimo                    int64
# codigo_barras                   object
# data_renovacao          datetime64[ns]
# data_emprestimo         datetime64[ns]
# data_devolucao          datetime64[ns]
# matricula_ou_siape              object
# tipo_vinculo_usuario            object
# id_exemplar                      int64
# colecao                         object
# biblioteca                      object
# status_material                 object
# localizacao                      int64
# registro_sistema                 int64
# area_conhecimento               object
# dtype: object

# %%
dados_biblioteca['data_emprestimo'] = pd.to_datetime(dados_biblioteca['data_emprestimo'])
dados_biblioteca['data_devolucao'] = pd.to_datetime(dados_biblioteca['data_devolucao'])
dados_biblioteca['data_renovacao'] = pd.to_datetime(dados_biblioteca['data_renovacao'])

dados_biblioteca.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         726965       L095049 2010-03-31 12:41:08.684
# 2         709685       L167050                     NaT
# 3         717763       L167050                     NaT
# 4         729996       L167050 2010-03-17 09:08:26.874
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 1 2010-03-01 12:40:56.212 2010-04-30 14:42:35.366       2009121584.0
# 2 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934       2008023265.0
# 3 2010-02-11 11:16:30.335 2010-03-04 08:54:32.262       2008050352.0
# 4 2010-03-04 13:36:26.599 2010-03-31 18:04:29.669        200722565.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
dados_biblioteca.dtypes
# Out:
# id_emprestimo                    int64
# codigo_barras                   object
# data_renovacao          datetime64[ns]
# data_emprestimo         datetime64[ns]
# data_devolucao          datetime64[ns]
# matricula_ou_siape              object
# tipo_vinculo_usuario            object
# id_exemplar                      int64
# colecao                         object
# biblioteca                      object
# status_material                 object
# localizacao                      int64
# registro_sistema                 int64
# area_conhecimento               object
# dtype: object

# %%
import matplotlib.pyplot as plt

# Extraindo o ano
dados_biblioteca['ano'] = dados_biblioteca['data_emprestimo'].dt.year

# Contando a quantidade de empréstimos por ano
emprestimos_por_ano = dados_biblioteca.groupby('ano').size()

# Criando o gráfico de linhas
plt.figure(figsize=(10, 6))
plt.plot(emprestimos_por_ano.index, emprestimos_por_ano.values, marker='o', linestyle='-', color='b', label='Empréstimos de Livros')

# Adicionando título e rótulos aos eixos
plt.title('Quantidade de Empréstimos de Livros por Ano')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Empréstimos')
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# Como pode ser observado no gráfico, a maior quantidade de emprestimos foi realizada no ano de 2014, com quase 225.000 empréstimos realizados naquele ano. Em contrapartida, em 2020 houve a menor quantidade de empréstimos registrada, apenas 25.000, esse fato pode ser devido à pandemia de Covid-19 que ocorreu em 2020 e causou o afastamento dos alunos, não só das universidades, das salas de aula, causando, assim, essa drástica queda nos empréstimos de livros, quando comparados aos anos anteriores.

# %%
# Extraindo o ano
dados_biblioteca['mes'] = dados_biblioteca['data_emprestimo'].dt.month

# Contando a quantidade de empréstimos por mês
emprestimos_por_mes = dados_biblioteca.groupby('mes').size()

# Criando o gráfico de linhas
plt.figure(figsize=(10, 6))
plt.plot(emprestimos_por_mes.index, emprestimos_por_mes.values, marker='o', linestyle='-', color='b', label='Empréstimos de Livros')

# Adicionando título e rótulos aos eixos
plt.title('Quantidade de Empréstimos de Livros por Mês')
plt.xlabel('Mês')
plt.ylabel('Quantidade de Empréstimos')
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# Como é possível observar, a maior quantidade de empréstimos é realizada no mês de agosto, quando foram realizados mais de 225.000 empréstimos, e a menor quantidade de empréstimos foi realizada nos meses de Janeiro e dezembro, com pouco mais de 50.000 e 75.000, respectivamente. Isto pode ser devido ao fato de esses meses serem, em geral, quando ocorrem as férias de fim de ano, bem como os meses de Junho e Julho, que marcam o recesso do meio do ano.

# %% [markdown]
# Considerando que os meses de Janeiro, Junho, Julho e Dezembro se mostraram serem os meses de menor demanda, é possível gerenciar a programação de férias dos colaboradores para que ocorram nesses meses, bem como programar atividades que não sejam de atendimento ao usuário para estes períodos.

# %%
# Extraindo o ano
dados_biblioteca['horario'] = dados_biblioteca['data_emprestimo'].dt.hour

# Contando a quantidade de empréstimos por mês
emprestimos_por_hora = dados_biblioteca.groupby('horario').size()

# Criando o gráfico de linhas
plt.figure(figsize=(10, 6))
plt.bar(emprestimos_por_hora.index, emprestimos_por_hora.values, color='b', label='Empréstimos de Livros')

# Adicionando título e rótulos aos eixos
plt.title('Quantidade de Empréstimos de Livros por Hora')
plt.xlabel('Horário')
plt.ylabel('Quantidade de Empréstimos')
plt.legend()

# Exibindo o gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# Os horários com maior quantidade de empréstimos ao longo do dia são por volta das 10, 16, 17 e 18 horas.
# Por outro lado, os horários em qua há menos empréstimos realizados são por volta das 7 e das 22 horas, horários em que poderiam ser alocadas as demais atividades que não sejam de atendimento ao usuário. No entanto, por marcarem o início e final de expediente, uma alternativa seria por volta das 8 e das 19 horas, onde há um fluxo mais moderado de empréstimos.

# %% [markdown]
# ## Análise exploratória de dados e Variáveis categóricas

# %% [markdown]
# ### “Como se distribuem os empréstimos de exemplares pelos tipos de vínculo dos usuários?”

# %%
# Agrupando os dados por tipo de vínculo e contando a quantidade de exemplares emprestados
emprestimos_por_vinculo = dados_biblioteca.groupby('tipo_vinculo_usuario').size()

# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
emprestimos_por_vinculo.plot(kind='bar', color='red')
plt.title('Distribuição de Empréstimos por Tipo de Vínculo')
plt.xlabel('Tipo de Vínculo')
plt.ylabel('Quantidade de Empréstimos')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Como é possível observar na distribuição dos empréstimos por tipo de vínculo acima, o tipo de vínculo que mais realiza empréstimos é o de ALUNO DE GRADUAÇÃO, provavelmente devido a ser o maior público dentro da universidade.

# %% [markdown]
# ### Quais coleções são mais emprestadas?

# %%
# Agrupando os dados por coleção e contando a quantidade de exemplares emprestados

emprestimos_por_colecao = dados_biblioteca.groupby('colecao').size().sort_values(ascending=False)

# Criando o gráfico de barras
plt.figure(figsize=(12, 6))
emprestimos_por_colecao.head(10).plot(kind='bar', color='green')
plt.title('Top 10 Coleções Mais Emprestadas')
plt.xlabel('Coleção')
plt.ylabel('Quantidade de Empréstimos')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Como esperado, a coleção mais emprestada é o Acervo Circulante, composto dos livros da biblioteca.
# Embora outros tipos de materiais sejam armazenados em uma biblioteca universitária, estes não são tão acessados quanto o acervo principal.
# Vamos experimentar excluir os dados acerca do acervo circulante para que seja possível verificar os dados acerca das demais coleções:

# %%
dados_biblioteca['demais_colecoes'] = dados_biblioteca['colecao'].replace('Acervo Circulante', np.nan)

emprestimos_por_colecao2 = dados_biblioteca.groupby('demais_colecoes').size().sort_values(ascending=False)

# Criando o gráfico de barras
plt.figure(figsize=(12, 6))
emprestimos_por_colecao2.head(10).plot(kind='bar', color='green')
plt.title('Top 10 Coleções Mais Emprestadas')
plt.xlabel('Coleção')
plt.ylabel('Quantidade de Empréstimos')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Como esperado, agora dá para visualizar melhor a significância dos empréstimos das demais coleções, agora é possível notar a real quantidade de empréstimos de coleções que pareciam ser 0 quando comparadas ao acervo circulante.

# %% [markdown]
# ### Quais são as bibliotecas com mais ou menos quantidade de empréstimos?

# %%
# Agrupando os dados por biblioteca e contando a quantidade de empréstimos
emprestimos_por_biblioteca = dados_biblioteca.groupby('biblioteca').size().sort_values(ascending=False)

# Exibindo as bibliotecas com mais empréstimos
print("Bibliotecas com mais empréstimos:")
print(emprestimos_por_biblioteca.head(3))

# Exibindo as bibliotecas com menos empréstimos
print("\nBibliotecas com menos empréstimos:")
print(emprestimos_por_biblioteca.tail(3))

# Criando o gráfico de barras
plt.figure(figsize=(12, 6))
emprestimos_por_biblioteca.plot(kind='bar', color='green')
plt.title('Quantidade de Empréstimos por Biblioteca')
plt.xlabel('Biblioteca')
plt.ylabel('Quantidade de Empréstimos')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Bibliotecas com mais empréstimos:
# biblioteca
# Biblioteca Central Zila Mamede                                                           1256285
# Biblioteca Setorial do Centro Ciências da Saúde - CCS                                     101001
# Biblioteca Setorial da Faculdade de Ciências da Saúde do Trairi - FACISA - Santa Cruz      66748
# dtype: int64
#
# Bibliotecas com menos empréstimos:
# biblioteca
# Biblioteca Setorial Moacyr de Góes - CE                                           924
# Biblioteca Setorial Árvore do Conhecimento - Instituto do Cérebro - ICe           860
# Biblioteca Setorial do Núcleo de Ensino Superior do Agreste - NESA - Nova Cruz    616
# dtype: int64
# <ipython-input-23-0f0b627d5ed8>:19: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### De quais temas da CDU são os exemplares emprestados?

# %%
def gerar_tabela_frequencia(dataframe, coluna):
  """
  Gera uma tabela de frequência e percentual para uma coluna categórica em um DataFrame.

  Args:
    dataframe: O DataFrame contendo os dados.
    coluna: O nome da coluna categórica a ser analisada.

  Returns:
    Um DataFrame com as frequências e percentuais.
  """

  frequencia = dataframe[coluna].value_counts()
  percentual = (frequencia / frequencia.sum()) * 100
  tabela = pd.DataFrame({'Frequência': frequencia, 'Percentual (%)': percentual})
  return tabela

# %%
temas = gerar_tabela_frequencia(dados_biblioteca, 'area_conhecimento')
temas
# Out:
#                                        Frequência  Percentual (%)
# area_conhecimento
# Ciências aplicadas                        1205402       65.711720
# Ciências Sociais                           336235       18.329636
# Matemática e ciências naturais              67970        3.705341
# Generalidades. Ciência e conhecimento       61908        3.374875
# Religião                                    61521        3.353778
# Filosofia e psicologia                      59993        3.270480
# Não identificado                            18538        1.010587
# Geografia. Biografia. História               7753        0.422650
# Belas artes                                  7704        0.419979
# Linguagem. Língua. Linguística               7355        0.400953

# %% [markdown]
# A maioria dos exemplares emprestados são da área de ciências aplicadas, como é possível perceber, seguido de ciências sociais e matemática  e ciências naturais.
# Sabendo disso, poderia ser uma boa estratégia deixar os livros desses temas mais acessíveis fisicamente e em uma área de destaque, como próximo à entrada da biblioteca, por exemplo.

# %%
# prompt: plotar com os temas

# Criando o gráfico de barras
plt.figure(figsize=(12, 6))
temas['Frequência'].plot(kind='bar', color='purple')
plt.title('Quantidade de Empréstimos por Área de Conhecimento')
plt.xlabel('Área de Conhecimento')
plt.ylabel('Quantidade de Empréstimos')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# A plotagem das áreas de conhecimento permite visualizar melhor as diferenças entre as quantidades de empréstimos das diferentes áreas.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importando dados de emprestimos

# %%
data_sources = [
  'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv',
  'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv'
]

data_frames = []
for url in data_sources:
  data_frames.append(pd.read_csv(url, on_bad_lines='skip'))

# %% [markdown]
# ## Unindo os datasets de emprestimos

# %%
emprestimos = pd.concat(data_frames)
emprestimos
# Out:
#       id_emprestimo codigo_barras                 data_renovacao  \
# 0          709684.0       L095049                            NaN
# 1          709685.0       L167050                            NaN
# 2          709686.0    2006017618  2010/01/26 08:07:01.738000000
# 3          709687.0       L184117  2010/01/18 11:07:46.470000000
# 4          709684.0       L095049                            NaN
# ...             ...           ...                            ...
# 1457            NaN           NaN                            NaN
# 1458            NaN           NaN                            NaN
# 1459            NaN           NaN                            NaN
# 1460            NaN           NaN                            NaN
# 1461            NaN           NaN                            NaN
#
#                     data_emprestimo                 data_devolucao  \
# 0     2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1     2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2     2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3     2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4     2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...                             ...                            ...
# 1457                            NaN                            NaN
# 1458                            NaN                            NaN
# 1459                            NaN                            NaN
# 1460                            NaN                            NaN
# 1461                            NaN                            NaN
#
#       matricula_ou_siape    tipo_vinculo_usuario  \
# 0           2.008023e+09      ALUNO DE GRADUAÇÃO
# 1           2.008023e+09      ALUNO DE GRADUAÇÃO
# 2           2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# 3           2.007211e+08      ALUNO DE GRADUAÇÃO
# 4           2.008023e+09      ALUNO DE GRADUAÇÃO
# ...                  ...                     ...
# 1457                 NaN                     NaN
# 1458                 NaN                     NaN
# 1459                 NaN                     NaN
# 1460                 NaN                     NaN
# 1461                 NaN                     NaN
#
#                                         <!DOCTYPE html>
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1457                                             </div>
# 1458      <div id="js-global-screen-reader-notice" c...
# 1459      <div id="js-global-screen-reader-notice-as...
# 1460                                            </body>
# 1461                                            </html>
#
# [122284 rows x 8 columns]

# %% [markdown]
# ## Verificando a existência de duplicadas e dados nulos e excluindo-os

# %%
# verificar dados duplicados

emprestimos.duplicated().sum()
# Out:
# 25404

# %%
# excluir dados duplicados

emprestimos.drop_duplicates(inplace=True)

# %% [markdown]
# ## Importando dados dos exemplares do acervo

# %%
# Importei baixando o arquivo e upando no colab em vez de direto do github, pq deste modo estava dando um erro e eu estava com dificuldades de solucionar
exemplares = pd.read_parquet('dados_exemplares.parquet')
exemplares
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# 3                          Biblioteca Central Zila Mamede         REGULAR
# 5                          Biblioteca Central Zila Mamede        ESPECIAL
# ...                                                   ...             ...
# 568580  Biblioteca Setorial do Núcleo de Educação da I...         REGULAR
# 568581                     Biblioteca Central Zila Mamede        ESPECIAL
# 568582                     Biblioteca Central Zila Mamede        ESPECIAL
# 568583                     Biblioteca Central Zila Mamede        ESPECIAL
# 568584                     Biblioteca Central Zila Mamede        ESPECIAL
#
#         localizacao  registro_sistema
# index
# 0               694                 1
# 1               688                 1
# 2               638                 1
# 3               616                 5
# 5               657                15
# ...             ...               ...
# 568580          951            268231
# 568581          997            268233
# 568582          987            268234
# 568583          764            268235
# 568584          962            268236
#
# [546237 rows x 7 columns]

# %% [markdown]
# ## Mesclando os datasets

# %%
dados_biblioteca = pd.merge(emprestimos, exemplares, on='codigo_barras')
dados_biblioteca
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 0           709684.0       L095049                            NaN
# 1           726965.0       L095049  2010/03/31 12:41:08.684000000
# 2           709685.0       L167050                            NaN
# 3           717763.0       L167050                            NaN
# 4           729996.0       L167050  2010/03/17 09:08:26.874000000
# ...              ...           ...                            ...
# 79387       799066.0       L177689                            NaN
# 79388       799073.0       L161739  2010/07/14 18:39:49.616000000
# 79389       799075.0    2009057818                            NaN
# 79390       799091.0    2007036834                            NaN
# 79391       799092.0    2009047162                            NaN
#
#                      data_emprestimo                 data_devolucao  \
# 0      2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1      2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2      2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3      2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4      2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
# ...                              ...                            ...
# 79387  2010/06/30 21:09:16.510000000  2010/08/03 18:36:20.000000000
# 79388  2010/06/30 21:16:43.687000000  2010/07/28 10:30:51.000000000
# 79389  2010/06/30 21:17:57.407000000  2010/07/05 16:49:23.000000000
# 79390  2010/06/30 21:30:54.277000000  2010/07/19 19:29:28.000000000
# 79391  2010/06/30 21:30:54.350000000  2010/07/19 19:29:24.000000000
#
#        matricula_ou_siape    tipo_vinculo_usuario <!DOCTYPE html>  \
# 0            2.008023e+09      ALUNO DE GRADUAÇÃO             NaN
# 1            2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO             NaN
# 2            2.008023e+09      ALUNO DE GRADUAÇÃO             NaN
# 3            2.008050e+09      ALUNO DE GRADUAÇÃO             NaN
# 4            2.007226e+08      ALUNO DE GRADUAÇÃO             NaN
# ...                   ...                     ...             ...
# 79387        2.009040e+09      ALUNO DE GRADUAÇÃO             NaN
# 79388        2.009013e+09      ALUNO DE GRADUAÇÃO             NaN
# 79389        2.005059e+08      ALUNO DE GRADUAÇÃO             NaN
# 79390        2.005052e+08      ALUNO DE GRADUAÇÃO             NaN
# 79391        2.005052e+08      ALUNO DE GRADUAÇÃO             NaN
#
#        id_exemplar            colecao                      biblioteca  \
# 0            13259  Acervo Circulante  Biblioteca Central Zila Mamede
# 1            13259  Acervo Circulante  Biblioteca Central Zila Mamede
# 2            70865  Acervo Circulante  Biblioteca Central Zila Mamede
# 3            70865  Acervo Circulante  Biblioteca Central Zila Mamede
# 4            70865  Acervo Circulante  Biblioteca Central Zila Mamede
# ...            ...                ...                             ...
# 79387       115969  Acervo Circulante  Biblioteca Central Zila Mamede
# 79388        44739  Acervo Circulante  Biblioteca Central Zila Mamede
# 79389       286931  Acervo Circulante  Biblioteca Central Zila Mamede
# 79390       235889  Acervo Circulante  Biblioteca Central Zila Mamede
# 79391       279481  Acervo Circulante  Biblioteca Central Zila Mamede
#
#       status_material  localizacao  registro_sistema
# 0             REGULAR          630              4225
# 1             REGULAR          630              4225
# 2             REGULAR          647             25009
# 3             REGULAR          647             25009
# 4             REGULAR          647             25009
# ...               ...          ...               ...
# 79387         REGULAR          655             38116
# 79388         REGULAR          647             17625
# 79389         REGULAR          657            125470
# 79390         REGULAR          663             97669
# 79391         REGULAR          607             80481
#
# [79392 rows x 14 columns]

# %% [markdown]
# ##Limpeza

# %% [markdown]
# ### Verificando dados nulos

# %%
dados_biblioteca.isnull().sum()
# Out:
# id_emprestimo               0
# codigo_barras               0
# data_renovacao          45545
# data_emprestimo             0
# data_devolucao              3
# matricula_ou_siape        176
# tipo_vinculo_usuario        0
# <!DOCTYPE html>         79392
# id_exemplar                 0
# colecao                     0
# biblioteca                  0
# status_material             0
# localizacao                 0
# registro_sistema            0
# dtype: int64

# %% [markdown]
# Os dados nulos em data_renovação existem porque nem todos os emprestimos foram renovados por mais tempo, portanto vou mantê-los, no entanto o atributo <!DOCTYPE html> não é um atributo de fato e irei excluí-lo

# %%
# Exluindo atributos desnecessários ou inadequados
dados_biblioteca.drop(columns=['<!DOCTYPE html>','registro_sistema'], inplace=True)
dados_biblioteca
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 0           709684.0       L095049                            NaN
# 1           726965.0       L095049  2010/03/31 12:41:08.684000000
# 2           709685.0       L167050                            NaN
# 3           717763.0       L167050                            NaN
# 4           729996.0       L167050  2010/03/17 09:08:26.874000000
# ...              ...           ...                            ...
# 79387       799066.0       L177689                            NaN
# 79388       799073.0       L161739  2010/07/14 18:39:49.616000000
# 79389       799075.0    2009057818                            NaN
# 79390       799091.0    2007036834                            NaN
# 79391       799092.0    2009047162                            NaN
#
#                      data_emprestimo                 data_devolucao  \
# 0      2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1      2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2      2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3      2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4      2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
# ...                              ...                            ...
# 79387  2010/06/30 21:09:16.510000000  2010/08/03 18:36:20.000000000
# 79388  2010/06/30 21:16:43.687000000  2010/07/28 10:30:51.000000000
# 79389  2010/06/30 21:17:57.407000000  2010/07/05 16:49:23.000000000
# 79390  2010/06/30 21:30:54.277000000  2010/07/19 19:29:28.000000000
# 79391  2010/06/30 21:30:54.350000000  2010/07/19 19:29:24.000000000
#
#        matricula_ou_siape    tipo_vinculo_usuario  id_exemplar  \
# 0            2.008023e+09      ALUNO DE GRADUAÇÃO        13259
# 1            2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259
# 2            2.008023e+09      ALUNO DE GRADUAÇÃO        70865
# 3            2.008050e+09      ALUNO DE GRADUAÇÃO        70865
# 4            2.007226e+08      ALUNO DE GRADUAÇÃO        70865
# ...                   ...                     ...          ...
# 79387        2.009040e+09      ALUNO DE GRADUAÇÃO       115969
# 79388        2.009013e+09      ALUNO DE GRADUAÇÃO        44739
# 79389        2.005059e+08      ALUNO DE GRADUAÇÃO       286931
# 79390        2.005052e+08      ALUNO DE GRADUAÇÃO       235889
# 79391        2.005052e+08      ALUNO DE GRADUAÇÃO       279481
#
#                  colecao                      biblioteca status_material  \
# 0      Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 1      Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 2      Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 3      Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 4      Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# ...                  ...                             ...             ...
# 79387  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 79388  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 79389  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 79390  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# 79391  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
#
#        localizacao
# 0              630
# 1              630
# 2              647
# 3              647
# 4              647
# ...            ...
# 79387          655
# 79388          647
# 79389          657
# 79390          663
# 79391          607
#
# [79392 rows x 12 columns]

# %%
dados_biblioteca['matricula_ou_siape'] = dados_biblioteca['matricula_ou_siape'].astype('str')
dados_biblioteca.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0       709684.0       L095049                            NaN
# 1       726965.0       L095049  2010/03/31 12:41:08.684000000
# 2       709685.0       L167050                            NaN
# 3       717763.0       L167050                            NaN
# 4       729996.0       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1       2009121584.0  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2       2008023265.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3       2008050352.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        200722565.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647

# %% [markdown]
# 000 a 099: Generalidades. Ciência e conhecimento.
#
# ---
#
#
# 100 a 199: Filosofia e psicologia.
#
# ---
#
#
# 200 a 299: Religião.
#
# ---
#
#
# 300 a 399: Ciências sociais.
#
# ---
#
#
# 400 a 499: Classe vaga. Provisoriamente não ocupada.
#
# ---
#
#
# 500 a 599: Matemática e ciências naturais.
#
# ---
#
#
# 600 a 699: Ciências aplicadas.
#
# ---
#
#
# 700 a 799: Belas artes.
#
# ---
#
#
# 800 a 899: Linguagem. Língua. Linguística.
#
# ---
#
#
# 900 a 999: Geografia. Biografia. História.

# %%
def localizar_area(localizacao):
  if localizacao >= 000 and localizacao < 99:
    return 'Generalidades. Ciência e conhecimento'
  elif localizacao >= 100 and localizacao < 199:
    return 'Filosofia e psicologia'
  elif localizacao >= 200 and localizacao < 299:
    return 'Religião'
  elif localizacao >= 300 and localizacao < 399:
    return 'Ciências Sociais'
  elif localizacao >= 400 and localizacao < 499:
    return 'Classe vaga. Provisoriamente não ocupada'
  elif localizacao >= 500 and localizacao < 599:
    return 'Matemática e ciências naturais'
  elif localizacao >= 600 and localizacao < 699:
    return 'Ciências aplicadas'
  elif localizacao >= 700 and localizacao < 799:
    return 'Belas artes'
  elif localizacao >= 800 and localizacao < 899:
    return 'Linguagem. Língua. Linguística'
  elif localizacao >= 900 and localizacao < 999:
    return 'Geografia. Biografia. História'
  else:
    return 'Não identificado'

# %%
dados_biblioteca['area_conhecimento'] = dados_biblioteca['localizacao'].apply(localizar_area)
dados_biblioteca.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0       709684.0       L095049                            NaN
# 1       726965.0       L095049  2010/03/31 12:41:08.684000000
# 2       709685.0       L167050                            NaN
# 3       717763.0       L167050                            NaN
# 4       729996.0       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1       2009121584.0  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2       2008023265.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3       2008050352.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        200722565.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#     area_conhecimento
# 0  Ciências aplicadas
# 1  Ciências aplicadas
# 2  Ciências aplicadas
# 3  Ciências aplicadas
# 4  Ciências aplicadas
